# %% [markdown]
# ## Step 1: Install and Import Libraries
# - Installed required libraries using pip.
# - Imported necessary modules for data loading, preprocessing, feature engineering, model training, and evaluation.
# - Libraries used: pandas, numpy, scikit-learn, xgboost, lightgbm, imbalanced-learn, boto3 (for S3 integration).

# %%
# -----------------------------------------------
# STEP 1: Import Libraries
# -----------------------------------------------

# !pip install pandas numpy scikit-learn xgboost lightgbm imbalanced-learn boto3

import boto3
import pandas as pd
import numpy as np
import io
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: xgboost in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: lightgbm in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (4.6.0)
# Requirement already satisfied: imbalanced-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (1.37.36)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: botocore<1.38.0,>=1.37.36 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (1.37.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from boto3) (0.11.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from botocore<1.38.0,>=1.37.36->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.17.0)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/core.py:377: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc >= 2.28) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(

# %% [markdown]
# ## Step 2: Load Dataset from S3
# - Connected to AWS S3 using boto3 client.
# - Loaded the LAPD Crime Dataset directly into a pandas DataFrame.
# - Parsed date columns to datetime format to enable temporal feature extraction.

# %%
# -----------------------------------------------
# STEP 2: Load Data
# -----------------------------------------------
s3 = boto3.client('s3')
bucket_name = 'mlc-project-1'
file_key = 'Crime_Data_from_2020_to_Present.csv'

response = s3.get_object(Bucket=bucket_name, Key=file_key)
crime_df = pd.read_csv(io.BytesIO(response['Body'].read()))
crime_df['DATE OCC'] = pd.to_datetime(crime_df['DATE OCC'], format='%m/%d/%Y', errors='coerce')

required_cols = [
    'Crm Cd Desc', 'TIME OCC', 'LAT', 'LON', 'AREA NAME',
    'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Desc'
]
crime_df = crime_df.dropna(subset=required_cols)
print("Step 2: Data loaded. Shape:", crime_df.shape)
# Out:
# Step 2: Data loaded. Shape: (859829, 28)

# %% [markdown]
# ## Step 3: Feature Engineering
# - Extracted important time-based features (Hour, Day of Week, Month).
# - Created binary indicators (Night Time, Weekend).
# - Calculated Distance from Downtown LA for spatial analysis.
# - Grouped crime types into three categories: Assault, Burglary, and Other to simplify the multi-class classification problem.
# - Added Victim Age interactions and apply KMeans clustering on geolocation (LAT, LON) data.

# %%
# -----------------------------------------------
# STEP 3: Feature Engineering
# -----------------------------------------------
crime_df['TIME OCC'] = crime_df['TIME OCC'].astype(str).str.zfill(4)
crime_df['Hour'] = crime_df['TIME OCC'].str[:2].astype(int)
crime_df['DayOfWeek'] = crime_df['DATE OCC'].dt.dayofweek
crime_df['Month'] = crime_df['DATE OCC'].dt.month
crime_df['Is_Night'] = crime_df['Hour'].apply(lambda x: 1 if x >= 22 or x <= 5 else 0)
crime_df['Is_Weekend'] = crime_df['DayOfWeek'].apply(lambda x: 1 if x in [5, 6] else 0)
crime_df['DistanceFromDowntown'] = ((crime_df['LAT'] - 34.05)**2 + (crime_df['LON'] + 118.25)**2)**0.5

def group_crime(row):
    if row == 'BATTERY - SIMPLE ASSAULT':
        return 'Assault'
    elif row == 'BURGLARY FROM VEHICLE':
        return 'Burglary'
    else:
        return 'Other'
crime_df['Crime_Group'] = crime_df['Crm Cd Desc'].apply(group_crime)

crime_df['VictAge_Weekend'] = crime_df['Vict Age'] * crime_df['Is_Weekend']
crime_df['Cluster'] = KMeans(n_clusters=15, random_state=42).fit_predict(crime_df[['LAT', 'LON']])

print("Step 3: Feature Engineering completed.")
# Out:
# Step 3: Feature Engineering completed.

# %% [markdown]
# ## Step 4: Data Preparation
# - Selected key predictive features related to time, location, demographics, and premises.
# - Performed one-hot encoding on categorical variables.
# - Ensured feature names are clean and compatible for ML modeling.

# %%
# -----------------------------------------------
# STEP 4: Prepare Features
# -----------------------------------------------
features = [
    'Hour', 'LAT', 'LON', 'AREA NAME', 'Vict Age', 'Vict Sex', 'Vict Descent', 
    'Premis Desc', 'DayOfWeek', 'Month', 'Is_Night', 'Is_Weekend', 
    'DistanceFromDowntown', 'VictAge_Weekend', 'Cluster'
]
X = crime_df[features]
y = crime_df['Crime_Group'].astype('category')
y_cat = y.cat.codes

X_encoded = pd.get_dummies(X, drop_first=True)
X_encoded.columns = X_encoded.columns.str.replace('[^A-Za-z0-9_]', '_', regex=True)

print("Step 4: Features prepared. Shape:", X_encoded.shape)
# Out:
# Step 4: Features prepared. Shape: (859829, 359)

# %% [markdown]
# ## Step 5: Dimensionality Reduction
# - Handled missing values using SimpleImputer (mean strategy).
# - Applied TruncatedSVD to reduce dimensionality and improve model efficiency without major loss of information.
# - This step significantly speeds up model training and avoids memory issues in AWS SageMaker.

# %%
# -----------------------------------------------
# STEP 5: Imputation + Dimensionality Reduction
# -----------------------------------------------
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X_encoded)

svd = TruncatedSVD(n_components=100, random_state=42)
X_reduced = svd.fit_transform(X_imputed)

print("Step 5: SVD Dimensionality Reduction done. Shape:", X_reduced.shape)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['DayOfWeek' 'Month']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# Step 5: SVD Dimensionality Reduction done. Shape: (859829, 100)

# %% [markdown]
# ## Step 6: Data Balancing with SMOTE
# - Addressed class imbalance using Synthetic Minority Oversampling Technique (SMOTE).
# - This helps the model learn from underrepresented crime categories properly.
# - Result: Balanced dataset for better generalization and fairness.

# %%
# -----------------------------------------------
# STEP 6: SMOTE
# -----------------------------------------------
smote = SMOTE(random_state=42)
X_balanced, y_balanced = smote.fit_resample(X_reduced, y_cat)

print("Step 6: SMOTE balancing done. Shape:", X_balanced.shape)
# Out:
# Step 6: SMOTE balancing done. Shape: (2164524, 100)

# %% [markdown]
# ## Step 7: Train -Test Split
# - Split the data into training and testing sets with stratified sampling to preserve class distributions.
# - 80% for training and 20% for testing.

# %%
# -----------------------------------------------
# STEP 7: Train-Test Split
# -----------------------------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X_balanced, y_balanced, stratify=y_balanced, test_size=0.2, random_state=42
)
print("Step 7: Train-test split complete.")
# Out:
# Step 7: Train-test split complete.

# %% [markdown]
# ## Step 8: Model Training
# - Trained three different models:
#   - Random Forest Classifier
#   - LightGBM Classifier
#   - XGBoost Classifier
# - Fine-tune hyperparameters manually for optimal performance.
# - Applied early stopping in XGBoost to avoid overfitting.

# %% [markdown]
# ## Random Forest

# %%
# -----------------------------------------------
# STEP 8: Train Individual Models
# -----------------------------------------------

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    max_features='sqrt',
    class_weight='balanced',
    n_jobs=-1,
    random_state=42
)
rf.fit(X_train, y_train)


print("Step 8: Random Forest model trained.")
# Out:
# Step 8: Random Forest model trained.

# %%
# -----------------------------------------------
# Evaluate Random Forest Model
# -----------------------------------------------

def evaluate_model(name, model):
    y_pred = model.predict(X_test)
    print(f"\n{name} Evaluation:")
    print(classification_report(y_test, y_pred))
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
   
evaluate_model("Random Forest", rf)
# Out:
# Random Forest Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.68      0.68      0.68    144301
#            1       0.68      0.85      0.75    144302
#            2       0.76      0.57      0.65    144302
#
#     accuracy                           0.70    432905
#    macro avg       0.71      0.70      0.69    432905
# weighted avg       0.71      0.70      0.69    432905
#
# Accuracy: 0.6991

# %% [markdown]
# ## Random Forest Accuracy ~ 70%
#
# Summary:
# Quick to train but struggles with complex crime patterns. Performs better for Burglary but less accurate for Other crimes. Good baseline model but limited for deeper insights.

# %% [markdown]
# ## LightGBM

# %%
lgbm = LGBMClassifier(
    n_estimators=300,
    learning_rate=0.03,
    max_depth=8,
    random_state=42,
    n_jobs=-1
)
lgbm.fit(X_train, y_train)

print("Step 8: LGBMClassifier trained.")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.032473 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 1731619, number of used features: 100
# [LightGBM] [Info] Start training from score -1.098611
# [LightGBM] [Info] Start training from score -1.098613
# [LightGBM] [Info] Start training from score -1.098613
# Step 8: LGBMClassifier trained.

# %%
# -----------------------------------------------
# Evaluate LightGBM Model
# -----------------------------------------------
def evaluate_model(name, model):
    y_pred = model.predict(X_test)
    print(f"\n{name} Evaluation:")
    print(classification_report(y_test, y_pred))
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

evaluate_model("LightGBM", lgbm)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# LightGBM Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.74      0.69      0.72    144301
#            1       0.71      0.85      0.78    144302
#            2       0.76      0.67      0.71    144302
#
#     accuracy                           0.74    432905
#    macro avg       0.74      0.74      0.74    432905
# weighted avg       0.74      0.74      0.74    432905
#
# Accuracy: 0.7375

# %% [markdown]
# ## LightGBM Accuracy ~ 74%
# More efficient than Random Forest. Handles Burglary crimes well but shows slight bias towards common classes. Faster training, moderate performance improvement.

# %% [markdown]
# ## XGBoost Model

# %%
xgb = XGBClassifier(
    n_estimators=1000,
    max_depth=12,
    learning_rate=0.015,
    subsample=0.85,
    colsample_bytree=0.75,
    gamma=0.2,
    reg_alpha=0.8,
    reg_lambda=1.2,
    objective='multi:softprob',
    eval_metric='mlogloss',
    early_stopping_rounds=30,
    use_label_encoder=False,
    n_jobs=-1,
    random_state=42
)

xgb.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=True
)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/xgboost/callback.py:386: UserWarning: [20:30:55] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.09092
# [1]	validation_0-mlogloss:1.08327
# [2]	validation_0-mlogloss:1.07538
# [3]	validation_0-mlogloss:1.06788
# [4]	validation_0-mlogloss:1.06078
# [5]	validation_0-mlogloss:1.05350
# [6]	validation_0-mlogloss:1.04645
# [7]	validation_0-mlogloss:1.03931
# [8]	validation_0-mlogloss:1.03254
# [9]	validation_0-mlogloss:1.02613
# [10]	validation_0-mlogloss:1.01997
# [11]	validation_0-mlogloss:1.01375
# [12]	validation_0-mlogloss:1.00742
# [13]	validation_0-mlogloss:1.00124
# [14]	validation_0-mlogloss:0.99535
# [15]	validation_0-mlogloss:0.98923
# [16]	validation_0-mlogloss:0.98320
# [17]	validation_0-mlogloss:0.97754
# [18]	validation_0-mlogloss:0.97219
# [19]	validation_0-mlogloss:0.96689
# [20]	validation_0-mlogloss:0.96175
# [21]	validation_0-mlogloss:0.95691
# [22]	validation_0-mlogloss:0.95178
# [23]	validation_0-mlogloss:0.94673
# [24]	validation_0-mlogloss:0.94173
# [25]	validation_0-mlogloss:0.93682
# [26]	validation_0-mlogloss:0.93215
# [27]	validation_0-mlogloss:0.92742
# [28]	validation_0-mlogloss:0.92279
# [29]	validation_0-mlogloss:0.91826
# [30]	validation_0-mlogloss:0.91385
# [31]	validation_0-mlogloss:0.90942
# [32]	validation_0-mlogloss:0.90502
# [33]	validation_0-mlogloss:0.90072
# [34]	validation_0-mlogloss:0.89655
# [35]	validation_0-mlogloss:0.89236
# [36]	validation_0-mlogloss:0.88831
# [37]	validation_0-mlogloss:0.88424
# [38]	validation_0-mlogloss:0.88041
# [39]	validation_0-mlogloss:0.87659
# [40]	validation_0-mlogloss:0.87271
# [41]	validation_0-mlogloss:0.86883
# [42]	validation_0-mlogloss:0.86523
# [43]	validation_0-mlogloss:0.86155
# [44]	validation_0-mlogloss:0.85791
# [45]	validation_0-mlogloss:0.85451
# [46]	validation_0-mlogloss:0.85111
# [47]	validation_0-mlogloss:0.84751
# [48]	validation_0-mlogloss:0.84399
# [49]	validation_0-mlogloss:0.84071
# [50]	validation_0-mlogloss:0.83745
# [51]	validation_0-mlogloss:0.83421
# [52]	validation_0-mlogloss:0.83113
# [53]	validation_0-mlogloss:0.82806
# [54]	validation_0-mlogloss:0.82504
# [55]	validation_0-mlogloss:0.82226
# [56]	validation_0-mlogloss:0.81931
# [57]	validation_0-mlogloss:0.81643
# [58]	validation_0-mlogloss:0.81370
# [59]	validation_0-mlogloss:0.81095
# [60]	validation_0-mlogloss:0.80804
# [61]	validation_0-mlogloss:0.80515
# [62]	validation_0-mlogloss:0.80249
# [63]	validation_0-mlogloss:0.79991
# [64]	validation_0-mlogloss:0.79737
# [65]	validation_0-mlogloss:0.79481
# [66]	validation_0-mlogloss:0.79218
# [67]	validation_0-mlogloss:0.78968
# [68]	validation_0-mlogloss:0.78729
# [69]	validation_0-mlogloss:0.78498
# [70]	validation_0-mlogloss:0.78242
# [71]	validation_0-mlogloss:0.78005
# [72]	validation_0-mlogloss:0.77762
# [73]	validation_0-mlogloss:0.77527
# [74]	validation_0-mlogloss:0.77305
# [75]	validation_0-mlogloss:0.77084
# [76]	validation_0-mlogloss:0.76865
# [77]	validation_0-mlogloss:0.76650
# [78]	validation_0-mlogloss:0.76423
# [79]	validation_0-mlogloss:0.76215
# [80]	validation_0-mlogloss:0.75986
# [81]	validation_0-mlogloss:0.75775
# [82]	validation_0-mlogloss:0.75565
# [83]	validation_0-mlogloss:0.75371
# [84]	validation_0-mlogloss:0.75178
# [85]	validation_0-mlogloss:0.74987
# [86]	validation_0-mlogloss:0.74796
# [87]	validation_0-mlogloss:0.74596
# [88]	validation_0-mlogloss:0.74418
# [89]	validation_0-mlogloss:0.74235
# [90]	validation_0-mlogloss:0.74056
# [91]	validation_0-mlogloss:0.73889
# [92]	validation_0-mlogloss:0.73700
# [93]	validation_0-mlogloss:0.73529
# [94]	validation_0-mlogloss:0.73364
# [95]	validation_0-mlogloss:0.73195
# [96]	validation_0-mlogloss:0.73021
# [97]	validation_0-mlogloss:0.72837
# [98]	validation_0-mlogloss:0.72674
# [99]	validation_0-mlogloss:0.72515
# [100]	validation_0-mlogloss:0.72360
# [101]	validation_0-mlogloss:0.72199
# [102]	validation_0-mlogloss:0.72034
# [103]	validation_0-mlogloss:0.71882
# [104]	validation_0-mlogloss:0.71734
# [105]	validation_0-mlogloss:0.71578
# [106]	validation_0-mlogloss:0.71431
# [107]	validation_0-mlogloss:0.71271
# [108]	validation_0-mlogloss:0.71120
# [109]	validation_0-mlogloss:0.70970
# [110]	validation_0-mlogloss:0.70822
# [111]	validation_0-mlogloss:0.70686
# [112]	validation_0-mlogloss:0.70542
# [113]	validation_0-mlogloss:0.70407
# [114]	validation_0-mlogloss:0.70268
# [115]	validation_0-mlogloss:0.70133
# [116]	validation_0-mlogloss:0.70000
# [117]	validation_0-mlogloss:0.69871
# [118]	validation_0-mlogloss:0.69733
# [119]	validation_0-mlogloss:0.69596
# [120]	validation_0-mlogloss:0.69477
# [121]	validation_0-mlogloss:0.69348
# [122]	validation_0-mlogloss:0.69209
# [123]	validation_0-mlogloss:0.69086
# [124]	validation_0-mlogloss:0.68956
# [125]	validation_0-mlogloss:0.68835
# [126]	validation_0-mlogloss:0.68689
# [127]	validation_0-mlogloss:0.68573
# [128]	validation_0-mlogloss:0.68450
# [129]	validation_0-mlogloss:0.68326
# [130]	validation_0-mlogloss:0.68207
# [131]	validation_0-mlogloss:0.68091
# [132]	validation_0-mlogloss:0.67964
# [133]	validation_0-mlogloss:0.67853
# [134]	validation_0-mlogloss:0.67743
# [135]	validation_0-mlogloss:0.67626
# [136]	validation_0-mlogloss:0.67520
# [137]	validation_0-mlogloss:0.67415
# [138]	validation_0-mlogloss:0.67311
# [139]	validation_0-mlogloss:0.67183
# [140]	validation_0-mlogloss:0.67076
# [141]	validation_0-mlogloss:0.66966
# [142]	validation_0-mlogloss:0.66869
# [143]	validation_0-mlogloss:0.66740
# [144]	validation_0-mlogloss:0.66637
# [145]	validation_0-mlogloss:0.66534
# [146]	validation_0-mlogloss:0.66419
# [147]	validation_0-mlogloss:0.66317
# [148]	validation_0-mlogloss:0.66205
# [149]	validation_0-mlogloss:0.66117
# [150]	validation_0-mlogloss:0.66018
# [151]	validation_0-mlogloss:0.65913
# [152]	validation_0-mlogloss:0.65804
# [153]	validation_0-mlogloss:0.65694
# [154]	validation_0-mlogloss:0.65593
# [155]	validation_0-mlogloss:0.65510
# [156]	validation_0-mlogloss:0.65406
# [157]	validation_0-mlogloss:0.65312
# [158]	validation_0-mlogloss:0.65229
# [159]	validation_0-mlogloss:0.65142
# [160]	validation_0-mlogloss:0.65046
# [161]	validation_0-mlogloss:0.64960
# [162]	validation_0-mlogloss:0.64879
# [163]	validation_0-mlogloss:0.64780
# [164]	validation_0-mlogloss:0.64679
# [165]	validation_0-mlogloss:0.64591
# [166]	validation_0-mlogloss:0.64493
# [167]	validation_0-mlogloss:0.64403
# [168]	validation_0-mlogloss:0.64330
# [169]	validation_0-mlogloss:0.64236
# [170]	validation_0-mlogloss:0.64164
# [171]	validation_0-mlogloss:0.64076
# [172]	validation_0-mlogloss:0.64002
# [173]	validation_0-mlogloss:0.63926
# [174]	validation_0-mlogloss:0.63849
# [175]	validation_0-mlogloss:0.63772
# [176]	validation_0-mlogloss:0.63695
# [177]	validation_0-mlogloss:0.63608
# [178]	validation_0-mlogloss:0.63526
# [179]	validation_0-mlogloss:0.63452
# [180]	validation_0-mlogloss:0.63383
# [181]	validation_0-mlogloss:0.63312
# [182]	validation_0-mlogloss:0.63244
# [183]	validation_0-mlogloss:0.63168
# [184]	validation_0-mlogloss:0.63086
# [185]	validation_0-mlogloss:0.63015
# [186]	validation_0-mlogloss:0.62946
# [187]	validation_0-mlogloss:0.62874
# [188]	validation_0-mlogloss:0.62800
# [189]	validation_0-mlogloss:0.62721
# [190]	validation_0-mlogloss:0.62658
# [191]	validation_0-mlogloss:0.62598
# [192]	validation_0-mlogloss:0.62534
# [193]	validation_0-mlogloss:0.62473
# [194]	validation_0-mlogloss:0.62412
# [195]	validation_0-mlogloss:0.62342
# [196]	validation_0-mlogloss:0.62276
# [197]	validation_0-mlogloss:0.62198
# [198]	validation_0-mlogloss:0.62137
# [199]	validation_0-mlogloss:0.62071
# [200]	validation_0-mlogloss:0.62013
# [201]	validation_0-mlogloss:0.61935
# [202]	validation_0-mlogloss:0.61868
# [203]	validation_0-mlogloss:0.61794
# [204]	validation_0-mlogloss:0.61736
# [205]	validation_0-mlogloss:0.61671
# [206]	validation_0-mlogloss:0.61611
# [207]	validation_0-mlogloss:0.61556
# [208]	validation_0-mlogloss:0.61496
# [209]	validation_0-mlogloss:0.61442
# [210]	validation_0-mlogloss:0.61378
# [211]	validation_0-mlogloss:0.61317
# [212]	validation_0-mlogloss:0.61241
# [213]	validation_0-mlogloss:0.61179
# [214]	validation_0-mlogloss:0.61128
# [215]	validation_0-mlogloss:0.61058
# [216]	validation_0-mlogloss:0.60986
# [217]	validation_0-mlogloss:0.60933
# [218]	validation_0-mlogloss:0.60860
# [219]	validation_0-mlogloss:0.60795
# [220]	validation_0-mlogloss:0.60743
# [221]	validation_0-mlogloss:0.60677
# [222]	validation_0-mlogloss:0.60615
# [223]	validation_0-mlogloss:0.60567
# [224]	validation_0-mlogloss:0.60503
# [225]	validation_0-mlogloss:0.60437
# [226]	validation_0-mlogloss:0.60383
# [227]	validation_0-mlogloss:0.60321
# [228]	validation_0-mlogloss:0.60264
# [229]	validation_0-mlogloss:0.60207
# [230]	validation_0-mlogloss:0.60162
# [231]	validation_0-mlogloss:0.60107
# [232]	validation_0-mlogloss:0.60063
# [233]	validation_0-mlogloss:0.60008
# [234]	validation_0-mlogloss:0.59959
# [235]	validation_0-mlogloss:0.59904
# [236]	validation_0-mlogloss:0.59854
# [237]	validation_0-mlogloss:0.59808
# [238]	validation_0-mlogloss:0.59757
# [239]	validation_0-mlogloss:0.59696
# [240]	validation_0-mlogloss:0.59647
# [241]	validation_0-mlogloss:0.59591
# [242]	validation_0-mlogloss:0.59545
# [243]	validation_0-mlogloss:0.59486
# [244]	validation_0-mlogloss:0.59422
# [245]	validation_0-mlogloss:0.59370
# [246]	validation_0-mlogloss:0.59321
# [247]	validation_0-mlogloss:0.59270
# [248]	validation_0-mlogloss:0.59223
# [249]	validation_0-mlogloss:0.59181
# [250]	validation_0-mlogloss:0.59139
# [251]	validation_0-mlogloss:0.59093
# [252]	validation_0-mlogloss:0.59046
# [253]	validation_0-mlogloss:0.59002
# [254]	validation_0-mlogloss:0.58964
# [255]	validation_0-mlogloss:0.58922
# [256]	validation_0-mlogloss:0.58875
# [257]	validation_0-mlogloss:0.58831
# [258]	validation_0-mlogloss:0.58786
# [259]	validation_0-mlogloss:0.58738
# [260]	validation_0-mlogloss:0.58690
# [261]	validation_0-mlogloss:0.58641
# [262]	validation_0-mlogloss:0.58601
# [263]	validation_0-mlogloss:0.58554
# [264]	validation_0-mlogloss:0.58509
# [265]	validation_0-mlogloss:0.58470
# [266]	validation_0-mlogloss:0.58427
# [267]	validation_0-mlogloss:0.58390
# [268]	validation_0-mlogloss:0.58351
# [269]	validation_0-mlogloss:0.58312
# [270]	validation_0-mlogloss:0.58259
# [271]	validation_0-mlogloss:0.58224
# [272]	validation_0-mlogloss:0.58172
# [273]	validation_0-mlogloss:0.58135
# [274]	validation_0-mlogloss:0.58080
# [275]	validation_0-mlogloss:0.58042
# [276]	validation_0-mlogloss:0.58004
# [277]	validation_0-mlogloss:0.57966
# [278]	validation_0-mlogloss:0.57921
# [279]	validation_0-mlogloss:0.57880
# [280]	validation_0-mlogloss:0.57840
# [281]	validation_0-mlogloss:0.57798
# [282]	validation_0-mlogloss:0.57757
# [283]	validation_0-mlogloss:0.57720
# [284]	validation_0-mlogloss:0.57674
# [285]	validation_0-mlogloss:0.57641
# [286]	validation_0-mlogloss:0.57610
# [287]	validation_0-mlogloss:0.57567
# [288]	validation_0-mlogloss:0.57533
# [289]	validation_0-mlogloss:0.57497
# [290]	validation_0-mlogloss:0.57449
# [291]	validation_0-mlogloss:0.57397
# [292]	validation_0-mlogloss:0.57358
# [293]	validation_0-mlogloss:0.57318
# [294]	validation_0-mlogloss:0.57285
# [295]	validation_0-mlogloss:0.57248
# [296]	validation_0-mlogloss:0.57217
# [297]	validation_0-mlogloss:0.57185
# [298]	validation_0-mlogloss:0.57148
# [299]	validation_0-mlogloss:0.57113
# [300]	validation_0-mlogloss:0.57075
# [301]	validation_0-mlogloss:0.57035
# [302]	validation_0-mlogloss:0.57005
# [303]	validation_0-mlogloss:0.56976
# [304]	validation_0-mlogloss:0.56943
# [305]	validation_0-mlogloss:0.56903
# [306]	validation_0-mlogloss:0.56859
# [307]	validation_0-mlogloss:0.56813
# [308]	validation_0-mlogloss:0.56764
# [309]	validation_0-mlogloss:0.56728
# [310]	validation_0-mlogloss:0.56692
# [311]	validation_0-mlogloss:0.56655
# [312]	validation_0-mlogloss:0.56620
# [313]	validation_0-mlogloss:0.56578
# [314]	validation_0-mlogloss:0.56541
# [315]	validation_0-mlogloss:0.56513
# [316]	validation_0-mlogloss:0.56485
# [317]	validation_0-mlogloss:0.56449
# [318]	validation_0-mlogloss:0.56404
# [319]	validation_0-mlogloss:0.56367
# [320]	validation_0-mlogloss:0.56327
# [321]	validation_0-mlogloss:0.56293
# [322]	validation_0-mlogloss:0.56248
# [323]	validation_0-mlogloss:0.56223
# [324]	validation_0-mlogloss:0.56190
# [325]	validation_0-mlogloss:0.56148
# [326]	validation_0-mlogloss:0.56109
# [327]	validation_0-mlogloss:0.56076
# [328]	validation_0-mlogloss:0.56041
# [329]	validation_0-mlogloss:0.56007
# [330]	validation_0-mlogloss:0.55975
# [331]	validation_0-mlogloss:0.55944
# [332]	validation_0-mlogloss:0.55917
# [333]	validation_0-mlogloss:0.55882
# [334]	validation_0-mlogloss:0.55834
# [335]	validation_0-mlogloss:0.55803
# [336]	validation_0-mlogloss:0.55769
# [337]	validation_0-mlogloss:0.55732
# [338]	validation_0-mlogloss:0.55699
# [339]	validation_0-mlogloss:0.55669
# [340]	validation_0-mlogloss:0.55644
# [341]	validation_0-mlogloss:0.55603
# [342]	validation_0-mlogloss:0.55564
# [343]	validation_0-mlogloss:0.55524
# [344]	validation_0-mlogloss:0.55489
# [345]	validation_0-mlogloss:0.55447
# [346]	validation_0-mlogloss:0.55420
# [347]	validation_0-mlogloss:0.55390
# [348]	validation_0-mlogloss:0.55356
# [349]	validation_0-mlogloss:0.55321
# [350]	validation_0-mlogloss:0.55292
# [351]	validation_0-mlogloss:0.55264
# [352]	validation_0-mlogloss:0.55234
# [353]	validation_0-mlogloss:0.55191
# [354]	validation_0-mlogloss:0.55160
# [355]	validation_0-mlogloss:0.55136
# [356]	validation_0-mlogloss:0.55110
# [357]	validation_0-mlogloss:0.55075
# [358]	validation_0-mlogloss:0.55047
# [359]	validation_0-mlogloss:0.55019
# [360]	validation_0-mlogloss:0.54989
# [361]	validation_0-mlogloss:0.54962
# [362]	validation_0-mlogloss:0.54924
# [363]	validation_0-mlogloss:0.54890
# [364]	validation_0-mlogloss:0.54851
# [365]	validation_0-mlogloss:0.54824
# [366]	validation_0-mlogloss:0.54795
# [367]	validation_0-mlogloss:0.54756
# [368]	validation_0-mlogloss:0.54726
# [369]	validation_0-mlogloss:0.54698
# [370]	validation_0-mlogloss:0.54662
# [371]	validation_0-mlogloss:0.54635
# [372]	validation_0-mlogloss:0.54603
# [373]	validation_0-mlogloss:0.54574
# [374]	validation_0-mlogloss:0.54550
# [375]	validation_0-mlogloss:0.54518
# [376]	validation_0-mlogloss:0.54485
# [377]	validation_0-mlogloss:0.54459
# [378]	validation_0-mlogloss:0.54432
# [379]	validation_0-mlogloss:0.54408
# [380]	validation_0-mlogloss:0.54379
# [381]	validation_0-mlogloss:0.54349
# [382]	validation_0-mlogloss:0.54326
# [383]	validation_0-mlogloss:0.54297
# [384]	validation_0-mlogloss:0.54267
# [385]	validation_0-mlogloss:0.54242
# [386]	validation_0-mlogloss:0.54216
# [387]	validation_0-mlogloss:0.54180
# [388]	validation_0-mlogloss:0.54156
# [389]	validation_0-mlogloss:0.54127
# [390]	validation_0-mlogloss:0.54094
# [391]	validation_0-mlogloss:0.54065
# [392]	validation_0-mlogloss:0.54036
# [393]	validation_0-mlogloss:0.54010
# [394]	validation_0-mlogloss:0.53977
# [395]	validation_0-mlogloss:0.53946
# [396]	validation_0-mlogloss:0.53921
# [397]	validation_0-mlogloss:0.53889
# [398]	validation_0-mlogloss:0.53862
# [399]	validation_0-mlogloss:0.53831
# [400]	validation_0-mlogloss:0.53805
# [401]	validation_0-mlogloss:0.53769
# [402]	validation_0-mlogloss:0.53742
# [403]	validation_0-mlogloss:0.53708
# [404]	validation_0-mlogloss:0.53675
# [405]	validation_0-mlogloss:0.53642
# [406]	validation_0-mlogloss:0.53610
# [407]	validation_0-mlogloss:0.53578
# [408]	validation_0-mlogloss:0.53557
# [409]	validation_0-mlogloss:0.53522
# [410]	validation_0-mlogloss:0.53483
# [411]	validation_0-mlogloss:0.53457
# [412]	validation_0-mlogloss:0.53426
# [413]	validation_0-mlogloss:0.53390
# [414]	validation_0-mlogloss:0.53362
# [415]	validation_0-mlogloss:0.53321
# [416]	validation_0-mlogloss:0.53294
# [417]	validation_0-mlogloss:0.53260
# [418]	validation_0-mlogloss:0.53232
# [419]	validation_0-mlogloss:0.53202
# [420]	validation_0-mlogloss:0.53173
# [421]	validation_0-mlogloss:0.53147
# [422]	validation_0-mlogloss:0.53121
# [423]	validation_0-mlogloss:0.53094
# [424]	validation_0-mlogloss:0.53067
# [425]	validation_0-mlogloss:0.53037
# [426]	validation_0-mlogloss:0.53013
# [427]	validation_0-mlogloss:0.52985
# [428]	validation_0-mlogloss:0.52953
# [429]	validation_0-mlogloss:0.52926
# [430]	validation_0-mlogloss:0.52902
# [431]	validation_0-mlogloss:0.52871
# [432]	validation_0-mlogloss:0.52848
# [433]	validation_0-mlogloss:0.52817
# [434]	validation_0-mlogloss:0.52787
# [435]	validation_0-mlogloss:0.52758
# [436]	validation_0-mlogloss:0.52731
# [437]	validation_0-mlogloss:0.52703
# [438]	validation_0-mlogloss:0.52677
# [439]	validation_0-mlogloss:0.52653
# [440]	validation_0-mlogloss:0.52618
# [441]	validation_0-mlogloss:0.52593
# [442]	validation_0-mlogloss:0.52565
# [443]	validation_0-mlogloss:0.52532
# [444]	validation_0-mlogloss:0.52503
# [445]	validation_0-mlogloss:0.52473
# [446]	validation_0-mlogloss:0.52445
# [447]	validation_0-mlogloss:0.52415
# [448]	validation_0-mlogloss:0.52386
# [449]	validation_0-mlogloss:0.52363
# [450]	validation_0-mlogloss:0.52336
# [451]	validation_0-mlogloss:0.52315
# [452]	validation_0-mlogloss:0.52291
# [453]	validation_0-mlogloss:0.52258
# [454]	validation_0-mlogloss:0.52230
# [455]	validation_0-mlogloss:0.52200
# [456]	validation_0-mlogloss:0.52177
# [457]	validation_0-mlogloss:0.52151
# [458]	validation_0-mlogloss:0.52121
# [459]	validation_0-mlogloss:0.52094
# [460]	validation_0-mlogloss:0.52060
# [461]	validation_0-mlogloss:0.52037
# [462]	validation_0-mlogloss:0.52009
# [463]	validation_0-mlogloss:0.51990
# [464]	validation_0-mlogloss:0.51966
# [465]	validation_0-mlogloss:0.51934
# [466]	validation_0-mlogloss:0.51906
# [467]	validation_0-mlogloss:0.51878
# [468]	validation_0-mlogloss:0.51857
# [469]	validation_0-mlogloss:0.51832
# [470]	validation_0-mlogloss:0.51803
# [471]	validation_0-mlogloss:0.51780
# [472]	validation_0-mlogloss:0.51756
# [473]	validation_0-mlogloss:0.51726
# [474]	validation_0-mlogloss:0.51709
# [475]	validation_0-mlogloss:0.51678
# [476]	validation_0-mlogloss:0.51653
# [477]	validation_0-mlogloss:0.51624
# [478]	validation_0-mlogloss:0.51603
# [479]	validation_0-mlogloss:0.51584
# [480]	validation_0-mlogloss:0.51567
# [481]	validation_0-mlogloss:0.51538
# [482]	validation_0-mlogloss:0.51518
# [483]	validation_0-mlogloss:0.51484
# [484]	validation_0-mlogloss:0.51466
# [485]	validation_0-mlogloss:0.51446
# [486]	validation_0-mlogloss:0.51418
# [487]	validation_0-mlogloss:0.51391
# [488]	validation_0-mlogloss:0.51376
# [489]	validation_0-mlogloss:0.51361
# [490]	validation_0-mlogloss:0.51327
# [491]	validation_0-mlogloss:0.51300
# [492]	validation_0-mlogloss:0.51286
# [493]	validation_0-mlogloss:0.51265
# [494]	validation_0-mlogloss:0.51247
# [495]	validation_0-mlogloss:0.51215
# [496]	validation_0-mlogloss:0.51190
# [497]	validation_0-mlogloss:0.51165
# [498]	validation_0-mlogloss:0.51145
# [499]	validation_0-mlogloss:0.51118
# [500]	validation_0-mlogloss:0.51095
# [501]	validation_0-mlogloss:0.51071
# [502]	validation_0-mlogloss:0.51038
# [503]	validation_0-mlogloss:0.51019
# [504]	validation_0-mlogloss:0.51000
# [505]	validation_0-mlogloss:0.50977
# [506]	validation_0-mlogloss:0.50955
# [507]	validation_0-mlogloss:0.50936
# [508]	validation_0-mlogloss:0.50917
# [509]	validation_0-mlogloss:0.50897
# [510]	validation_0-mlogloss:0.50869
# [511]	validation_0-mlogloss:0.50850
# [512]	validation_0-mlogloss:0.50828
# [513]	validation_0-mlogloss:0.50806
# [514]	validation_0-mlogloss:0.50791
# [515]	validation_0-mlogloss:0.50762
# [516]	validation_0-mlogloss:0.50743
# [517]	validation_0-mlogloss:0.50724
# [518]	validation_0-mlogloss:0.50695
# [519]	validation_0-mlogloss:0.50672
# [520]	validation_0-mlogloss:0.50647
# [521]	validation_0-mlogloss:0.50624
# [522]	validation_0-mlogloss:0.50598
# [523]	validation_0-mlogloss:0.50581
# [524]	validation_0-mlogloss:0.50559
# [525]	validation_0-mlogloss:0.50531
# [526]	validation_0-mlogloss:0.50507
# [527]	validation_0-mlogloss:0.50484
# [528]	validation_0-mlogloss:0.50463
# [529]	validation_0-mlogloss:0.50448
# [530]	validation_0-mlogloss:0.50417
# [531]	validation_0-mlogloss:0.50401
# [532]	validation_0-mlogloss:0.50383
# [533]	validation_0-mlogloss:0.50361
# [534]	validation_0-mlogloss:0.50336
# [535]	validation_0-mlogloss:0.50313
# [536]	validation_0-mlogloss:0.50291
# [537]	validation_0-mlogloss:0.50271
# [538]	validation_0-mlogloss:0.50258
# [539]	validation_0-mlogloss:0.50235
# [540]	validation_0-mlogloss:0.50213
# [541]	validation_0-mlogloss:0.50193
# [542]	validation_0-mlogloss:0.50170
# [543]	validation_0-mlogloss:0.50150
# [544]	validation_0-mlogloss:0.50127
# [545]	validation_0-mlogloss:0.50106
# [546]	validation_0-mlogloss:0.50086
# [547]	validation_0-mlogloss:0.50064
# [548]	validation_0-mlogloss:0.50037
# [549]	validation_0-mlogloss:0.50023
# [550]	validation_0-mlogloss:0.50007
# [551]	validation_0-mlogloss:0.49986
# [552]	validation_0-mlogloss:0.49969
# [553]	validation_0-mlogloss:0.49950
# [554]	validation_0-mlogloss:0.49926
# [555]	validation_0-mlogloss:0.49909
# [556]	validation_0-mlogloss:0.49879
# [557]	validation_0-mlogloss:0.49858
# [558]	validation_0-mlogloss:0.49841
# [559]	validation_0-mlogloss:0.49822
# [560]	validation_0-mlogloss:0.49804
# [561]	validation_0-mlogloss:0.49789
# [562]	validation_0-mlogloss:0.49771
# [563]	validation_0-mlogloss:0.49746
# [564]	validation_0-mlogloss:0.49724
# [565]	validation_0-mlogloss:0.49708
# [566]	validation_0-mlogloss:0.49691
# [567]	validation_0-mlogloss:0.49677
# [568]	validation_0-mlogloss:0.49654
# [569]	validation_0-mlogloss:0.49635
# [570]	validation_0-mlogloss:0.49616
# [571]	validation_0-mlogloss:0.49596
# [572]	validation_0-mlogloss:0.49573
# [573]	validation_0-mlogloss:0.49547
# [574]	validation_0-mlogloss:0.49536
# [575]	validation_0-mlogloss:0.49516
# [576]	validation_0-mlogloss:0.49504
# [577]	validation_0-mlogloss:0.49487
# [578]	validation_0-mlogloss:0.49462
# [579]	validation_0-mlogloss:0.49439
# [580]	validation_0-mlogloss:0.49420
# [581]	validation_0-mlogloss:0.49403
# [582]	validation_0-mlogloss:0.49387
# [583]	validation_0-mlogloss:0.49364
# [584]	validation_0-mlogloss:0.49343
# [585]	validation_0-mlogloss:0.49329
# [586]	validation_0-mlogloss:0.49315
# [587]	validation_0-mlogloss:0.49295
# [588]	validation_0-mlogloss:0.49272
# [589]	validation_0-mlogloss:0.49249
# [590]	validation_0-mlogloss:0.49230
# [591]	validation_0-mlogloss:0.49209
# [592]	validation_0-mlogloss:0.49189
# [593]	validation_0-mlogloss:0.49168
# [594]	validation_0-mlogloss:0.49137
# [595]	validation_0-mlogloss:0.49117
# [596]	validation_0-mlogloss:0.49095
# [597]	validation_0-mlogloss:0.49073
# [598]	validation_0-mlogloss:0.49059
# [599]	validation_0-mlogloss:0.49042
# [600]	validation_0-mlogloss:0.49023
# [601]	validation_0-mlogloss:0.48999
# [602]	validation_0-mlogloss:0.48977
# [603]	validation_0-mlogloss:0.48955
# [604]	validation_0-mlogloss:0.48935
# [605]	validation_0-mlogloss:0.48906
# [606]	validation_0-mlogloss:0.48887
# [607]	validation_0-mlogloss:0.48866
# [608]	validation_0-mlogloss:0.48845
# [609]	validation_0-mlogloss:0.48826
# [610]	validation_0-mlogloss:0.48803
# [611]	validation_0-mlogloss:0.48778
# [612]	validation_0-mlogloss:0.48754
# [613]	validation_0-mlogloss:0.48734
# [614]	validation_0-mlogloss:0.48708
# [615]	validation_0-mlogloss:0.48692
# [616]	validation_0-mlogloss:0.48676
# [617]	validation_0-mlogloss:0.48654
# [618]	validation_0-mlogloss:0.48629
# [619]	validation_0-mlogloss:0.48611
# [620]	validation_0-mlogloss:0.48591
# [621]	validation_0-mlogloss:0.48572
# [622]	validation_0-mlogloss:0.48556
# [623]	validation_0-mlogloss:0.48542
# [624]	validation_0-mlogloss:0.48525
# [625]	validation_0-mlogloss:0.48511
# [626]	validation_0-mlogloss:0.48495
# [627]	validation_0-mlogloss:0.48479
# [628]	validation_0-mlogloss:0.48462
# [629]	validation_0-mlogloss:0.48439
# [630]	validation_0-mlogloss:0.48424
# [631]	validation_0-mlogloss:0.48405
# [632]	validation_0-mlogloss:0.48392
# [633]	validation_0-mlogloss:0.48378
# [634]	validation_0-mlogloss:0.48362
# [635]	validation_0-mlogloss:0.48348
# [636]	validation_0-mlogloss:0.48330
# [637]	validation_0-mlogloss:0.48318
# [638]	validation_0-mlogloss:0.48300
# [639]	validation_0-mlogloss:0.48286
# [640]	validation_0-mlogloss:0.48264
# [641]	validation_0-mlogloss:0.48250
# [642]	validation_0-mlogloss:0.48229
# [643]	validation_0-mlogloss:0.48209
# [644]	validation_0-mlogloss:0.48197
# [645]	validation_0-mlogloss:0.48179
# [646]	validation_0-mlogloss:0.48157
# [647]	validation_0-mlogloss:0.48135
# [648]	validation_0-mlogloss:0.48111
# [649]	validation_0-mlogloss:0.48097
# [650]	validation_0-mlogloss:0.48077
# [651]	validation_0-mlogloss:0.48058
# [652]	validation_0-mlogloss:0.48039
# [653]	validation_0-mlogloss:0.48022
# [654]	validation_0-mlogloss:0.48001
# [655]	validation_0-mlogloss:0.47988
# [656]	validation_0-mlogloss:0.47973
# [657]	validation_0-mlogloss:0.47960
# [658]	validation_0-mlogloss:0.47944
# [659]	validation_0-mlogloss:0.47925
# [660]	validation_0-mlogloss:0.47905
# [661]	validation_0-mlogloss:0.47889
# [662]	validation_0-mlogloss:0.47869
# [663]	validation_0-mlogloss:0.47847
# [664]	validation_0-mlogloss:0.47821
# [665]	validation_0-mlogloss:0.47804
# [666]	validation_0-mlogloss:0.47788
# [667]	validation_0-mlogloss:0.47775
# [668]	validation_0-mlogloss:0.47759
# [669]	validation_0-mlogloss:0.47744
# [670]	validation_0-mlogloss:0.47732
# [671]	validation_0-mlogloss:0.47715
# [672]	validation_0-mlogloss:0.47695
# [673]	validation_0-mlogloss:0.47676
# [674]	validation_0-mlogloss:0.47658
# [675]	validation_0-mlogloss:0.47640
# [676]	validation_0-mlogloss:0.47620
# [677]	validation_0-mlogloss:0.47601
# [678]	validation_0-mlogloss:0.47588
# [679]	validation_0-mlogloss:0.47569
# [680]	validation_0-mlogloss:0.47544
# [681]	validation_0-mlogloss:0.47531
# [682]	validation_0-mlogloss:0.47517
# [683]	validation_0-mlogloss:0.47502
# [684]	validation_0-mlogloss:0.47484
# [685]	validation_0-mlogloss:0.47473
# [686]	validation_0-mlogloss:0.47459
# [687]	validation_0-mlogloss:0.47445
# [688]	validation_0-mlogloss:0.47431
# [689]	validation_0-mlogloss:0.47413
# [690]	validation_0-mlogloss:0.47396
# [691]	validation_0-mlogloss:0.47378
# [692]	validation_0-mlogloss:0.47364
# [693]	validation_0-mlogloss:0.47351
# [694]	validation_0-mlogloss:0.47338
# [695]	validation_0-mlogloss:0.47324
# [696]	validation_0-mlogloss:0.47310
# [697]	validation_0-mlogloss:0.47296
# [698]	validation_0-mlogloss:0.47272
# [699]	validation_0-mlogloss:0.47254
# [700]	validation_0-mlogloss:0.47244
# [701]	validation_0-mlogloss:0.47224
# [702]	validation_0-mlogloss:0.47210
# [703]	validation_0-mlogloss:0.47194
# [704]	validation_0-mlogloss:0.47174
# [705]	validation_0-mlogloss:0.47161
# [706]	validation_0-mlogloss:0.47151
# [707]	validation_0-mlogloss:0.47137
# [708]	validation_0-mlogloss:0.47122
# [709]	validation_0-mlogloss:0.47104
# [710]	validation_0-mlogloss:0.47092
# [711]	validation_0-mlogloss:0.47074
# [712]	validation_0-mlogloss:0.47054
# [713]	validation_0-mlogloss:0.47041
# [714]	validation_0-mlogloss:0.47027
# [715]	validation_0-mlogloss:0.47017
# [716]	validation_0-mlogloss:0.47001
# [717]	validation_0-mlogloss:0.46983
# [718]	validation_0-mlogloss:0.46970
# [719]	validation_0-mlogloss:0.46953
# [720]	validation_0-mlogloss:0.46930
# [721]	validation_0-mlogloss:0.46920
# [722]	validation_0-mlogloss:0.46903
# [723]	validation_0-mlogloss:0.46887
# [724]	validation_0-mlogloss:0.46871
# [725]	validation_0-mlogloss:0.46854
# [726]	validation_0-mlogloss:0.46834
# [727]	validation_0-mlogloss:0.46813
# [728]	validation_0-mlogloss:0.46797
# [729]	validation_0-mlogloss:0.46786
# [730]	validation_0-mlogloss:0.46771
# [731]	validation_0-mlogloss:0.46748
# [732]	validation_0-mlogloss:0.46733
# [733]	validation_0-mlogloss:0.46719
# [734]	validation_0-mlogloss:0.46705
# [735]	validation_0-mlogloss:0.46687
# [736]	validation_0-mlogloss:0.46677
# [737]	validation_0-mlogloss:0.46664
# [738]	validation_0-mlogloss:0.46653
# [739]	validation_0-mlogloss:0.46635
# [740]	validation_0-mlogloss:0.46620
# [741]	validation_0-mlogloss:0.46610
# [742]	validation_0-mlogloss:0.46598
# [743]	validation_0-mlogloss:0.46587
# [744]	validation_0-mlogloss:0.46571
# [745]	validation_0-mlogloss:0.46556
# [746]	validation_0-mlogloss:0.46542
# [747]	validation_0-mlogloss:0.46522
# [748]	validation_0-mlogloss:0.46508
# [749]	validation_0-mlogloss:0.46489
# [750]	validation_0-mlogloss:0.46470
# [751]	validation_0-mlogloss:0.46455
# [752]	validation_0-mlogloss:0.46441
# [753]	validation_0-mlogloss:0.46418
# [754]	validation_0-mlogloss:0.46403
# [755]	validation_0-mlogloss:0.46385
# [756]	validation_0-mlogloss:0.46372
# [757]	validation_0-mlogloss:0.46363
# [758]	validation_0-mlogloss:0.46347
# [759]	validation_0-mlogloss:0.46330
# [760]	validation_0-mlogloss:0.46313
# [761]	validation_0-mlogloss:0.46298
# [762]	validation_0-mlogloss:0.46277
# [763]	validation_0-mlogloss:0.46261
# [764]	validation_0-mlogloss:0.46248
# [765]	validation_0-mlogloss:0.46232
# [766]	validation_0-mlogloss:0.46222
# [767]	validation_0-mlogloss:0.46203
# [768]	validation_0-mlogloss:0.46192
# [769]	validation_0-mlogloss:0.46182
# [770]	validation_0-mlogloss:0.46169
# [771]	validation_0-mlogloss:0.46159
# [772]	validation_0-mlogloss:0.46144
# [773]	validation_0-mlogloss:0.46125
# [774]	validation_0-mlogloss:0.46114
# [775]	validation_0-mlogloss:0.46099
# [776]	validation_0-mlogloss:0.46088
# [777]	validation_0-mlogloss:0.46077
# [778]	validation_0-mlogloss:0.46064
# [779]	validation_0-mlogloss:0.46048
# [780]	validation_0-mlogloss:0.46035
# [781]	validation_0-mlogloss:0.46016
# [782]	validation_0-mlogloss:0.46001
# [783]	validation_0-mlogloss:0.45990
# [784]	validation_0-mlogloss:0.45972
# [785]	validation_0-mlogloss:0.45958
# [786]	validation_0-mlogloss:0.45944
# [787]	validation_0-mlogloss:0.45921
# [788]	validation_0-mlogloss:0.45909
# [789]	validation_0-mlogloss:0.45894
# [790]	validation_0-mlogloss:0.45880
# [791]	validation_0-mlogloss:0.45870
# [792]	validation_0-mlogloss:0.45859
# [793]	validation_0-mlogloss:0.45848
# [794]	validation_0-mlogloss:0.45836
# [795]	validation_0-mlogloss:0.45819
# [796]	validation_0-mlogloss:0.45804
# [797]	validation_0-mlogloss:0.45792
# [798]	validation_0-mlogloss:0.45778
# [799]	validation_0-mlogloss:0.45762
# [800]	validation_0-mlogloss:0.45747
# [801]	validation_0-mlogloss:0.45734
# [802]	validation_0-mlogloss:0.45722
# [803]	validation_0-mlogloss:0.45709
# [804]	validation_0-mlogloss:0.45701
# [805]	validation_0-mlogloss:0.45685
# [806]	validation_0-mlogloss:0.45673
# [807]	validation_0-mlogloss:0.45660
# [808]	validation_0-mlogloss:0.45644
# [809]	validation_0-mlogloss:0.45633
# [810]	validation_0-mlogloss:0.45619
# [811]	validation_0-mlogloss:0.45602
# [812]	validation_0-mlogloss:0.45589
# [813]	validation_0-mlogloss:0.45575
# [814]	validation_0-mlogloss:0.45558
# [815]	validation_0-mlogloss:0.45549
# [816]	validation_0-mlogloss:0.45539
# [817]	validation_0-mlogloss:0.45527
# [818]	validation_0-mlogloss:0.45516
# [819]	validation_0-mlogloss:0.45501
# [820]	validation_0-mlogloss:0.45482
# [821]	validation_0-mlogloss:0.45470
# [822]	validation_0-mlogloss:0.45460
# [823]	validation_0-mlogloss:0.45447
# [824]	validation_0-mlogloss:0.45432
# [825]	validation_0-mlogloss:0.45421
# [826]	validation_0-mlogloss:0.45410
# [827]	validation_0-mlogloss:0.45400
# [828]	validation_0-mlogloss:0.45387
# [829]	validation_0-mlogloss:0.45373
# [830]	validation_0-mlogloss:0.45359
# [831]	validation_0-mlogloss:0.45344
# [832]	validation_0-mlogloss:0.45333
# [833]	validation_0-mlogloss:0.45320
# [834]	validation_0-mlogloss:0.45301
# [835]	validation_0-mlogloss:0.45283
# [836]	validation_0-mlogloss:0.45266
# [837]	validation_0-mlogloss:0.45252
# [838]	validation_0-mlogloss:0.45237
# [839]	validation_0-mlogloss:0.45219
# [840]	validation_0-mlogloss:0.45208
# [841]	validation_0-mlogloss:0.45197
# [842]	validation_0-mlogloss:0.45186
# [843]	validation_0-mlogloss:0.45175
# [844]	validation_0-mlogloss:0.45163
# [845]	validation_0-mlogloss:0.45154
# [846]	validation_0-mlogloss:0.45139
# [847]	validation_0-mlogloss:0.45126
# [848]	validation_0-mlogloss:0.45112
# [849]	validation_0-mlogloss:0.45097
# [850]	validation_0-mlogloss:0.45084
# [851]	validation_0-mlogloss:0.45075
# [852]	validation_0-mlogloss:0.45062
# [853]	validation_0-mlogloss:0.45048
# [854]	validation_0-mlogloss:0.45035
# [855]	validation_0-mlogloss:0.45021
# [856]	validation_0-mlogloss:0.45010
# [857]	validation_0-mlogloss:0.45001
# [858]	validation_0-mlogloss:0.44984
# [859]	validation_0-mlogloss:0.44970
# [860]	validation_0-mlogloss:0.44957
# [861]	validation_0-mlogloss:0.44942
# [862]	validation_0-mlogloss:0.44924
# [863]	validation_0-mlogloss:0.44910
# [864]	validation_0-mlogloss:0.44900
# [865]	validation_0-mlogloss:0.44888
# [866]	validation_0-mlogloss:0.44878
# [867]	validation_0-mlogloss:0.44867
# [868]	validation_0-mlogloss:0.44854
# [869]	validation_0-mlogloss:0.44845
# [870]	validation_0-mlogloss:0.44835
# [871]	validation_0-mlogloss:0.44822
# [872]	validation_0-mlogloss:0.44812
# [873]	validation_0-mlogloss:0.44802
# [874]	validation_0-mlogloss:0.44792
# [875]	validation_0-mlogloss:0.44777
# [876]	validation_0-mlogloss:0.44768
# [877]	validation_0-mlogloss:0.44757
# [878]	validation_0-mlogloss:0.44741
# [879]	validation_0-mlogloss:0.44732
# [880]	validation_0-mlogloss:0.44718
# [881]	validation_0-mlogloss:0.44705
# [882]	validation_0-mlogloss:0.44696
# [883]	validation_0-mlogloss:0.44687
# [884]	validation_0-mlogloss:0.44679
# [885]	validation_0-mlogloss:0.44669
# [886]	validation_0-mlogloss:0.44657
# [887]	validation_0-mlogloss:0.44649
# [888]	validation_0-mlogloss:0.44636
# [889]	validation_0-mlogloss:0.44628
# [890]	validation_0-mlogloss:0.44615
# [891]	validation_0-mlogloss:0.44605
# [892]	validation_0-mlogloss:0.44591
# [893]	validation_0-mlogloss:0.44578
# [894]	validation_0-mlogloss:0.44567
# [895]	validation_0-mlogloss:0.44559
# [896]	validation_0-mlogloss:0.44546
# [897]	validation_0-mlogloss:0.44535
# [898]	validation_0-mlogloss:0.44523
# [899]	validation_0-mlogloss:0.44514
# [900]	validation_0-mlogloss:0.44499
# [901]	validation_0-mlogloss:0.44484
# [902]	validation_0-mlogloss:0.44472
# [903]	validation_0-mlogloss:0.44460
# [904]	validation_0-mlogloss:0.44449
# [905]	validation_0-mlogloss:0.44435
# [906]	validation_0-mlogloss:0.44418
# [907]	validation_0-mlogloss:0.44409
# [908]	validation_0-mlogloss:0.44395
# [909]	validation_0-mlogloss:0.44386
# [910]	validation_0-mlogloss:0.44373
# [911]	validation_0-mlogloss:0.44355
# [912]	validation_0-mlogloss:0.44346
# [913]	validation_0-mlogloss:0.44338
# [914]	validation_0-mlogloss:0.44327
# [915]	validation_0-mlogloss:0.44316
# [916]	validation_0-mlogloss:0.44308
# [917]	validation_0-mlogloss:0.44294
# [918]	validation_0-mlogloss:0.44281
# [919]	validation_0-mlogloss:0.44272
# [920]	validation_0-mlogloss:0.44263
# [921]	validation_0-mlogloss:0.44255
# [922]	validation_0-mlogloss:0.44243
# [923]	validation_0-mlogloss:0.44233
# [924]	validation_0-mlogloss:0.44220
# [925]	validation_0-mlogloss:0.44204
# [926]	validation_0-mlogloss:0.44193
# [927]	validation_0-mlogloss:0.44184
# [928]	validation_0-mlogloss:0.44174
# [929]	validation_0-mlogloss:0.44166
# [930]	validation_0-mlogloss:0.44158
# [931]	validation_0-mlogloss:0.44148
# [932]	validation_0-mlogloss:0.44138
# [933]	validation_0-mlogloss:0.44130
# [934]	validation_0-mlogloss:0.44120
# [935]	validation_0-mlogloss:0.44113
# [936]	validation_0-mlogloss:0.44103
# [937]	validation_0-mlogloss:0.44091
# [938]	validation_0-mlogloss:0.44079
# [939]	validation_0-mlogloss:0.44069
# [940]	validation_0-mlogloss:0.44059
# [941]	validation_0-mlogloss:0.44050
# [942]	validation_0-mlogloss:0.44039
# [943]	validation_0-mlogloss:0.44024
# [944]	validation_0-mlogloss:0.44007
# [945]	validation_0-mlogloss:0.43997
# [946]	validation_0-mlogloss:0.43985
# [947]	validation_0-mlogloss:0.43973
# [948]	validation_0-mlogloss:0.43961
# [949]	validation_0-mlogloss:0.43952
# [950]	validation_0-mlogloss:0.43944
# [951]	validation_0-mlogloss:0.43934
# [952]	validation_0-mlogloss:0.43923
# [953]	validation_0-mlogloss:0.43914
# [954]	validation_0-mlogloss:0.43902
# [955]	validation_0-mlogloss:0.43893
# [956]	validation_0-mlogloss:0.43884
# [957]	validation_0-mlogloss:0.43873
# [958]	validation_0-mlogloss:0.43859
# [959]	validation_0-mlogloss:0.43846
# [960]	validation_0-mlogloss:0.43834
# [961]	validation_0-mlogloss:0.43828
# [962]	validation_0-mlogloss:0.43814
# [963]	validation_0-mlogloss:0.43801
# [964]	validation_0-mlogloss:0.43790
# [965]	validation_0-mlogloss:0.43781
# [966]	validation_0-mlogloss:0.43773
# [967]	validation_0-mlogloss:0.43757
# [968]	validation_0-mlogloss:0.43742
# [969]	validation_0-mlogloss:0.43732
# [970]	validation_0-mlogloss:0.43724
# [971]	validation_0-mlogloss:0.43713
# [972]	validation_0-mlogloss:0.43702
# [973]	validation_0-mlogloss:0.43692
# [974]	validation_0-mlogloss:0.43684
# [975]	validation_0-mlogloss:0.43674
# [976]	validation_0-mlogloss:0.43661
# [977]	validation_0-mlogloss:0.43653
# [978]	validation_0-mlogloss:0.43642
# [979]	validation_0-mlogloss:0.43627
# [980]	validation_0-mlogloss:0.43617
# [981]	validation_0-mlogloss:0.43608
# [982]	validation_0-mlogloss:0.43600
# [983]	validation_0-mlogloss:0.43591
# [984]	validation_0-mlogloss:0.43581
# [985]	validation_0-mlogloss:0.43571
# [986]	validation_0-mlogloss:0.43561
# [987]	validation_0-mlogloss:0.43551
# [988]	validation_0-mlogloss:0.43544
# [989]	validation_0-mlogloss:0.43536
# [990]	validation_0-mlogloss:0.43529
# [991]	validation_0-mlogloss:0.43519
# [992]	validation_0-mlogloss:0.43510
# [993]	validation_0-mlogloss:0.43501
# [994]	validation_0-mlogloss:0.43492
# [995]	validation_0-mlogloss:0.43482
# [996]	validation_0-mlogloss:0.43471
# [997]	validation_0-mlogloss:0.43464
# [998]	validation_0-mlogloss:0.43455
# [999]	validation_0-mlogloss:0.43442
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.75, device=None, early_stopping_rounds=30,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=0.2,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.015, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=12, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
# -----------------------------------------------
# Evaluate XGBoost Model
# -----------------------------------------------
def evaluate_model(model, name):
    y_pred = model.predict(X_test)
    print(f"\nModel: {name}")
    print(classification_report(y_test, y_pred, target_names=y.cat.categories))
    print("Accuracy:", accuracy_score(y_test, y_pred))

evaluate_model(xgb, "XGBoost")
# Out:
# Model: XGBoost
#               precision    recall  f1-score   support
#
#      Assault       0.85      0.77      0.81    144301
#     Burglary       0.81      0.88      0.85    144302
#        Other       0.83      0.83      0.83    144302
#
#     accuracy                           0.83    432905
#    macro avg       0.83      0.83      0.83    432905
# weighted avg       0.83      0.83      0.83    432905
#
# Accuracy: 0.8287176170291404

# %% [markdown]
# ## XGBoost Accuracy ~ 83%
#
# Best-performing model overall. Balanced precision and recall across all crime types. Captures complex patterns, making it highly reliable for crime prediction tasks.
